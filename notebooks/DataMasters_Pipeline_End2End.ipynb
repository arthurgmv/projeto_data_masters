# %% [markdown]
# ###Setup

# %%
# %pip install faker python-dotenv
dbutils.library.restartPython()
print("✅ Ambiente configurado com sucesso!")
# Out:
# Requirement already satisfied: faker in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5ef5c7b3-189a-48c9-a1c3-b8352603395f/lib/python3.12/site-packages (40.1.2)
# Requirement already satisfied: python-dotenv in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5ef5c7b3-189a-48c9-a1c3-b8352603395f/lib/python3.12/site-packages (1.2.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Warning: statements after `dbutils.library.restartPython()` will execute before Python is restarted.
# ✅ Ambiente configurado com sucesso!

# %% [markdown]
# ###Bronze

# %%
from faker import Faker
from pyspark.sql import SparkSession
from pyspark.sql.types import *
import random
from datetime import datetime

print("🚀 Gerando dados em memória...")
spark = SparkSession.builder.getOrCreate()
fake = Faker('pt_BR')
dados = []

for _ in range(1000):
    dados.append((
        fake.uuid4(),
        datetime.now().isoformat(),
        fake.name(),
        fake.cpf(),
        fake.credit_card_number(),
        float(round(random.uniform(10.0, 5000.0), 2)),
        fake.city(),
        fake.state_abbr()
    ))

schema = StructType([
    StructField("id_transacao", StringType(), True),
    StructField("data_evento", StringType(), True),
    StructField("cliente_nome", StringType(), True),
    StructField("cliente_cpf", StringType(), True),
    StructField("cartao", StringType(), True),
    StructField("valor", DoubleType(), True),
    StructField("cidade", StringType(), True),
    StructField("estado", StringType(), True)
])

df_bronze = spark.createDataFrame(dados, schema)

df_bronze.createOrReplaceTempView("tb_bronze")

print("✅ Tabela 'tb_bronze' criada na memória!")
display(df_bronze)
# Out:
# 🚀 Gerando dados em memória...
# ✅ Tabela 'tb_bronze' criada na memória!
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_transacao</th><th>data_evento</th><th>cliente_nome</th><th>cliente_cpf</th><th>cartao</th><th>valor</th><th>cidade</th><th>estado</th></tr></thead><tbody><tr><td>78ca1acf-bb28-4e16-8309-1733810e9116</td><td>2026-01-22T01:45:33.176181</td><td>Allana Alves</td><td>542.978.031-60</td><td>213192373104023</td><td>1939.89</td><td>Aparecida dos Dourados</td><td>CE</td></tr><tr><td>6e41f02c-ab4d-453b-8944-95fc5a27173a</td><td>2026-01-22T01:45:33.176361</td><td>Maria Flor Câmara</td><td>361.489.527-00</td><td>6011174349670924</td><td>4863.04</td><td>Cavalcante da Prata</td><td>ES</td></tr><tr><td>dca4e968-4993-4703-8ba4-f18368eacb87</td><td>2026-01-22T01:45:33.176462</td><td>Sr. João Lucas Cavalcante</td><td>627.504.813-17</td><td>180064154766081</td><td>4354.77</td><td>Gomes do Campo</td><td>PE</td></tr><tr><td>33ee1e9d-789d-4cd0-aead-e5577d71b184</td><td>2026-01-22T01:45:33.176540</td><td>Ana Clara Montenegro</td><td>592.463.871-55</td><td>38587337331344</td><td>4440.41</td><td>Borges</td><td>SP</td></tr><tr><td>6d5279ef-d21e-4509-a38f-cc163d5fc8d7</td><td>2026-01-22T01:45:33.176604</td><td>Nathan Vasconcelos</td><td>129.386.457-91</td><td>213162740849410</td><td>238.05</td><td>da Conceição de da Paz</td><td>CE</td></tr><tr><td>642ef877-d865-499c-b86f-4c6de2d8b9f7</td><td>2026-01-22T01:45:33.176669</td><td>Rhavi Cunha</td><td>940.536.182-15</td><td>4031575320880739147</td><td>1575.07</td><td>Pinto</td><td>PA</td></tr><tr><td>8e07d7d9-9cf6-4f82-9c88-1f886ec305
-22T01:45:33.177040</td><td>Srta. Eduarda Azevedo</td><td>322.27</td><td>Cassiano</td><td>RS</td><td>***.***.***-04</td><td>**** **** **** 548</td></tr><tr><td>738d5c43-33fb-4777-b798-06c1eb27da59</td><td>2026-01-22T01:45:33.177101</td><td>Emanuel Correia</td><td>640.32</td><td>Cavalcanti da Praia</td><td>PR</td><td>***.***.***-29</td><td>**** **** **** 631</td></tr><tr><td>920f5e2c-85a1-4f84-b749-d0b53b40736c</td><td>2026-01-22T01:45:33.177159</td><td>Alexandre da Luz</td><td>2515.81</td><td>Sousa</td><td>ES</td><td>***.***.***-74</td><td>**** **** **** 8900</td></tr><tr><td>06927acd-f243-4a4b-9487-a78c2f1ec98b</td><td>2026-01-22T01:45:33.177219</td><td>Melissa Moraes</td><td>3038.36</td><td>Vasconcelos das Flores</td><td>SE</td><td>***.***.***-00</td><td>**** **** **** 6654</td></tr><tr><td>ceb579ac-8790-4a86-858e-87a5f3c1b248</td><td>2026-01-22T01:45:33.177283</td><td>Nathan Moura</td><td>4209.91</td><td>Albuquerque das Flores</td><td>SP</td><td>***.***.***-50</td><td>**** **** **** 0355</td></tr><tr><td>1dde1539-953f-4948-af13-c0d315171267</td><td>2026-01-22T01:45:33.177345</td><td>Henry Gabriel da Cunha</td><td>3191.48</td><td>Vasconcelos de Costa</td><td>PE</td><td>***.***.***-51</td><td>**** **** **** 424</td></tr><tr><td>c5a93278-178e-4e48-b746-94d60c4623b0</td><td>2026-01-22T01:45:33.177406 ...

# %% [markdown]
# ###Gold

# %%
from pyspark.sql.functions import sum, count, col, desc, round

print("💰 Calculando KPIs de Negócio...")

df_trusted = spark.table("tb_silver")

df_gold = df_trusted.groupBy("estado") \
    .agg(
        sum("valor").alias("total_vendas"),
        count("id_transacao").alias("qtd_transacoes")
    ) \
    .withColumn("total_vendas", round(col("total_vendas"), 2)) \
    .orderBy(desc("total_vendas"))

df_gold.createOrReplaceTempView("tb_gold")

print("✅ Tabela 'tb_gold' pronta para consumo!")
display(df_gold)
# Out:
# 💰 Calculando KPIs de Negócio...
# ✅ Tabela 'tb_gold' pronta para consumo!
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>estado</th><th>total_vendas</th><th>qtd_transacoes</th></tr></thead><tbody><tr><td>RS</td><td>127465.56</td><td>45</td></tr><tr><td>AC</td><td>126417.92</td><td>47</td></tr><tr><td>RJ</td><td>123690.07</td><td>41</td></tr><tr><td>PB</td><td>123552.0</td><td>48</td></tr><tr><td>TO</td><td>110193.93</td><td>43</td></tr><tr><td>MG</td><td>106156.74</td><td>40</td></tr><tr><td>PA</td><td>102897.2</td><td>43</td></tr><tr><td>AP</td><td>99871.35</td><td>34</td></tr><tr><td>AM</td><td>99697.19</td><td>46</td></tr><tr><td>PE</td><td>99176.64</td><td>45</td></tr><tr><td>ES</td><td>96039.8</td><td>36</td></tr><tr><td>RR</td><td>95194.22</td><td>40</td></tr><tr><td>PR</td><td>92416.23</td><td>37</td></tr><tr><td>SP</td><td>91639.58</td><td>40</td></tr><tr><td>BA</td><td>91481.87</td><td>34</td></tr><tr><td>SE</td><td>90206.95</td><td>40</td></tr><tr><td>CE</td><td>88466.07</td><td>34</td></tr><tr><td>MA</td><td>88329.04</td><td>36</td></tr><tr><td>GO</td><td>83070.0</td><td>32</td></tr><tr><td>DF</td><td>81777.03</td><td>30</td></tr><tr><td>MS</td><td>77311.25</td><td>31</td></tr><tr><td>PI</td><td>76286.69</td><td>27</td></tr><tr><td>RN</td><td>76169.43</td><td>33</td></tr><tr><td>SC</td><td>73465.57</td><td>33</td></tr><tr><td>AL</td><td>71805.7</td><td>25</td></tr><tr><td>MT</td><td>67883.12</td><td>28</td></tr><tr><td>RO</td><td>60617.93</td><td>32</td></tr></tbody></table></div>

# %% [markdown]
# ###Simulação de consulta do GOLD em estudo

# %%
# %sql
SELECT 
    estado,
    total_vendas,
    qtd_transacoes,
    concat('R$ ', format_number(total_vendas, 2)) as vendas_formatado
FROM tb_gold
WHERE total_vendas > 5000
ORDER BY total_vendas DESC
LIMIT 27
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>estado</th><th>total_vendas</th><th>qtd_transacoes</th><th>vendas_formatado</th></tr></thead><tbody><tr><td>RS</td><td>127465.56</td><td>45</td><td>R$ 127,465.56</td></tr><tr><td>AC</td><td>126417.92</td><td>47</td><td>R$ 126,417.92</td></tr><tr><td>RJ</td><td>123690.07</td><td>41</td><td>R$ 123,690.07</td></tr><tr><td>PB</td><td>123552.0</td><td>48</td><td>R$ 123,552.00</td></tr><tr><td>TO</td><td>110193.93</td><td>43</td><td>R$ 110,193.93</td></tr><tr><td>MG</td><td>106156.74</td><td>40</td><td>R$ 106,156.74</td></tr><tr><td>PA</td><td>102897.2</td><td>43</td><td>R$ 102,897.20</td></tr><tr><td>AP</td><td>99871.35</td><td>34</td><td>R$ 99,871.35</td></tr><tr><td>AM</td><td>99697.19</td><td>46</td><td>R$ 99,697.19</td></tr><tr><td>PE</td><td>99176.64</td><td>45</td><td>R$ 99,176.64</td></tr><tr><td>ES</td><td>96039.8</td><td>36</td><td>R$ 96,039.80</td></tr><tr><td>RR</td><td>95194.22</td><td>40</td><td>R$ 95,194.22</td></tr><tr><td>PR</td><td>92416.23</td><td>37</td><td>R$ 92,416.23</td></tr><tr><td>SP</td><td>91639.58</td><td>40</td><td>R$ 91,639.58</td></tr><tr><td>BA</td><td>91481.87</td><td>34</td><td>R$ 91,481.87</td></tr><tr><td>SE</td><td>90206.95</td><td>40</td><td>R$ 90,206.95</td></tr><tr><td>CE</td><td>88466.07</td><td>34</td><td>R$ 88,466.07</td></tr><tr><td>MA</td><td>88329.04</td><td>36</td><td>R$ 88,329.04</td></tr><tr><td>GO</td><td>83070.0</td><td>32</td><td>R$ 83,070.00</td></tr><tr><td>DF</td><td>81777.03</td><td>30</td><td>R$ 81,777.03</td></tr><tr><td>MS</td><td>77311.25</td><td>31</td><td>R$ 77,311.25</td></tr><tr><td>PI</td><td>76286.69</td><td>27</td><td>R$ 76,286.69</td></tr><tr><td>RN</td><td>76169.43</td><td>33</td><td>R$ 76,169.43</td></tr><tr><td>SC</td><td>73465.57</td><td>33</td><td>R$ 73,465.57</td></tr><tr><td>AL</td><td>71805.7</td><td>25</td><td>R$ 71,805.70</td></tr><tr><td>MT</td><td>67883.12</td><td>28</td><td>R$ 67,883.12</td></tr><tr><td>RO</td><td>60617.93</td><td>32</td><td>R$ 60,617.93</td></tr></tbody></table></div>
