# %% [markdown]
# # 🏦 Data Masters: Pipeline Híbrido (End-to-End)
#
# Este notebook demonstra a execução do pipeline **Data Masters** em ambiente Cloud (Databricks).
# Ele replica a lógica exata dos scripts locais, provando a portabilidade da arquitetura.
#
# ### 🏗️ Arquitetura Medallion
# 1. **Bronze:** Ingestão de dados sintéticos (Simulando API).
# 2. **Silver:** Limpeza, **Data Quality** e Anonimização (**LGPD**).
# 3. **Gold:** Agregação de KPIs de vendas por Estado.

# %% [markdown]
# ###Setup e Data Quality

# %%
# Instala biblioteca de dados falsos
# %pip install faker

dbutils.library.restartPython()

from pyspark.sql.functions import col, regexp_replace, sum, count, desc, round, current_timestamp
from pyspark.sql.types import *
from faker import Faker
import random
from datetime import datetime

class DataQuality:
    def __init__(self):
        print("🛡️ Guardião de Qualidade Inicializado")

    def check_nulls(self, df, columns):
        """Verifica nulos em colunas críticas"""
        print(f"   🔍 Verificando nulos em: {columns}")
        for c in columns:
            null_count = df.filter(col(c).isNull() | (col(c) == "")).count()
            if null_count > 0:
                print(f"   ⚠️ ALERTA: Coluna '{c}' tem {null_count} nulos!")
            else:
                print(f"   ✅ Coluna '{c}' está íntegra.")
    
    def check_positive_values(self, df, columns):
        """Verifica se valores numéricos são positivos"""
        print(f"   🔍 Verificando valores negativos em: {columns}")
        for c in columns:
            neg_count = df.filter(col(c) < 0).count()
            if neg_count > 0:
                print(f"   🚨 ERRO: Coluna '{c}' possui valores negativos!")
            else:
                print(f"   ✅ Coluna '{c}' contém apenas valores positivos.")

dq = DataQuality()
fake = Faker('pt_BR')
print("✅ Ambiente Configurado!")
# Out:
# Requirement already satisfied: faker in /local_disk0/.ephemeral_nfs/envs/pythonEnv-da2c8d33-a605-49ee-9ed4-03c9c435f6fd/lib/python3.12/site-packages (40.1.2)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Warning: statements after `dbutils.library.restartPython()` will execute before Python is restarted.
# 🛡️ Guardião de Qualidade Inicializado
# ✅ Ambiente Configurado!

# %% [markdown]
# ###Bronze

# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
from faker import Faker
import random
from datetime import datetime
import uuid

print("🚀 [BRONZE] Iniciando Ingestão de Dados...")

try:
    fake = Faker('pt_BR')
except NameError:
    fake = Faker('pt_BR')

def gerar_dados_fake(qtd=1000):
    dados = []
    estados = ["SP", "RJ", "MG", "RS", "SC", "BA", "PE", "AM", "DF", "GO"]
    
    for _ in range(qtd):
        dados.append((
            str(uuid.uuid4()),
            fake.date_time_this_year().isoformat(),
            round(random.uniform(10.0, 5000.0), 2),
            fake.name(),
            fake.cpf(),
            fake.credit_card_number(),
            fake.city(),
            random.choice(estados)
        ))
    return dados

schema = StructType([
    StructField("id_transacao", StringType(), True),
    StructField("data_evento", StringType(), True),
    StructField("valor", DoubleType(), True),
    StructField("cliente_nome", StringType(), True),
    StructField("cliente_cpf", StringType(), True),
    StructField("cartao", StringType(), True),
    StructField("cidade", StringType(), True),
    StructField("estado", StringType(), True)
])

dados = gerar_dados_fake(500)
a-e5c9-4a12-97e0-ca962802cc55</td><td>2026-01-07T00:23:17.801646</td><td>3048.5</td><td>Sarah Cirino</td><td>032.158.497-04</td><td>30159840556540</td><td>da Rosa</td><td>SC</td></tr><tr><td>69a62c58-9aa6-4c20-b046-54e7c2a99468</td><td>2026-01-12T22:37:23.377138</td><td>3270.59</td><td>Júlia Moreira</td><td>530.978.164-10</td><td>30296060218722</td><td>Vasconcelos do Galho</td><td>SC</td></tr><tr><td>c0fc0bc2-b522-4a56-b10d-853a4cec95d1</td><td>2026-01-03T20:20:16.468930</td><td>337.76</td><td>Joana Campos</td><td>861.403.927-13</td><td>371079798430109</td><td>Sá</td><td>DF</td></tr><tr><td>6ba8d27b-fb4e-4a2c-959c-7601d91e5d5b</td><td>2026-01-18T16:04:45.686965</td><td>3845.58</td><td>Zoe Sousa</td><td>417.652.083-35</td><td>6011834710150711</td><td>Duarte de Marques</td><td>RS</td></tr><tr><td>a3fb34ef-2b30-46e4-bae9-dfbb1c262a1c</td><td>2026-01-02T00:00:42.930698</td><td>4619.55</td><td>Srta. Alana Caldeira</td><td>396.207.481-31</td><td>4643892211773846</td><td>Castro</td><td>PE</td></tr><tr><td>fc32d9a5-81f1-4e0a-9862-2845002b99df</td><td>2026-01-11T12:33:14.077603</td><td>2327.55</td><td>Maria Laura da Cruz</td><td>203.649.587-74</td><td>4216065064014</td><td>Carvalho</td><td>GO</td></tr><tr><td>08425c51-bd7b-4290-84c2-afb6235a1a1a</td><td>2026-01-02T01:25:39.575242</td><td>343.61</td><td>Alexia Vasconcelos</td><td>143.560.297-80</td><td>3571725338666980</td><td>Pimenta</td><td>MG</td></tr><tr><td>aa5cb9e5-f6b7-48ea-95be-05c845871a87</td><td>2026-01-04T20:47:59.832823</td><td>4257.29</td><td>Dra. Ana Júlia Aparecida</td><td>257.410.396-34</td><td>3556412659756927</td><td>Lopes</t ...

# %% [markdown]
# ###Silver

# %%
from pyspark.sql.functions import col, regexp_replace

print("🚀 [SILVER] Iniciando Tratamento e Anonimização...")

try:
    df = spark.table("v_bronze_raw")
except Exception:
    print("❌ ERRO: A View 'v_bronze_raw' não foi encontrada. Rode a célula Bronze anterior!")
    dbutils.notebook.exit("1")

try:
    print("--- 🕵️ Executando Auditoria de Qualidade ---")
    dq.check_nulls(df, ["id_transacao", "cliente_nome"])
    dq.check_positive_values(df, ["valor"])
    print("------------------------------------------")
except NameError:
    print("⚠️ Aviso: Classe DataQuality não encontrada. Rode a Célula 1 de Setup.")

df_silver = df.withColumn(
    "cpf_mascarado", 
    regexp_replace(col("cliente_cpf"), r"\d{3}\.\d{3}\.\d{3}", "***.***.***")
).withColumn(
    "cartao_tokenizado",
    regexp_replace(col("cartao"), r"^.*(\d{4})$", "**** **** **** $1")
).drop("cliente_cpf", "cartao") 

df_silver.createOrReplaceTempView("v_silver_trusted")

print("✅ View 'v_silver_trusted' criada na memória (Dados anonimizados).")
display(spark.sql("SELECT id_transacao, valor, cpf_mascarado, cartao_tokenizado, estado FROM v_silver_trusted LIMIT 50"))
# Out:
# 🚀 [SILVER] Iniciando Tratamento e Anonimização...
# --- 🕵️ Executando Auditoria de Qualidade ---
# ⚠️ Aviso: Classe DataQuality não encontrada. Rode a Célula 1 de Setup.
# ✅ View 'v_silver_trusted' criada na memória (Dados anonimizados).
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id
><tr><td>08425c51-bd7b-4290-84c2-afb6235a1a1a</td><td>343.61</td><td>***.***.***-80</td><td>**** **** **** 6980</td><td>MG</td></tr><tr><td>aa5cb9e5-f6b7-48ea-95be-05c845871a87</td><td>4257.29</td><td>***.***.***-34</td><td>**** **** **** 6927</td><td>PE</td></tr><tr><td>dd48f647-8eed-4e0d-b99d-cbb0115770d2</td><td>1701.22</td><td>***.***.***-01</td><td>**** **** **** 5768</td><td>MG</td></tr><tr><td>0c1e5974-53e4-4784-adc5-b40722755419</td><td>3738.5</td><td>***.***.***-83</td><td>**** **** **** 8362</td><td>AM</td></tr><tr><td>5bf2fce6-fa90-4072-a102-d79497bf0b92</td><td>4924.45</td><td>***.***.***-00</td><td>**** **** **** 3703</td><td>GO</td></tr><tr><td>560cf65b-4e04-4207-96b2-fde972ee5f86</td><td>597.32</td><td>***.***.***-94</td><td>**** **** **** 6398</td><td>RJ</td></tr><tr><td>8b782862-ea44-408b-9acb-1f1931e216d2</td><td>1089.07</td><td>***.***.***-20</td><td>**** **** **** 8577</td><td>MG</td></tr><tr><td>10d1b12c-f799-4d66-bb57-61c02bbdb60c</td><td>1856.74</td><td>***.***.***-80</td><td>**** **** **** 2663</td><td>SC</td></tr><tr><td>06f624e4-dcfb-4480-92c4-da35721c48ff</td><td>2124.03</td><td>***.***.***-24</td><td>**** **** **** 5856</td><td>DF</td></tr><tr><td>edc0d376-d202-40d6-ba73-f834e63025c3</td><td>3663.44</td><td>***.***.***-26</td><td>**** **** **** 8984</td><td>RS</td></tr><tr><td>ee938b8e-8ca3-44d8-b83d-0af7c58ddd42</td><td>2270.07</td><td>***.***.***-13</td><td>**** **** **** 2498</td><td>GO</td></tr><tr><td>8dafcc41-1135-439d-83d0-ceeb282e2400</td><td>3849.12</td><td>***.***.***-65</td><td>**** **** **** 0440</td><td>RJ</td></tr><tr><td>50466fc9-fae5-4902-8b84-b51d39f6e764</td><td>1896.97</td><td>***.***.* ...

# %% [markdown]
# ###Gold

# %%
from pyspark.sql.functions import col, sum, count, desc, round

print("🚀 [GOLD] Calculando KPIs de Vendas por Estado...")

try:
    df_trusted = spark.table("v_silver_trusted")
except:
    print("❌ ERRO: View Silver não encontrada. Rode a célula anterior.")

df_gold = df_trusted.groupBy("estado") \
    .agg(
        sum("valor").alias("total_vendas"),
        count("id_transacao").alias("qtd_transacoes")
    ) \
    .withColumn("total_vendas", round(col("total_vendas"), 2)) \
    .orderBy(desc("total_vendas"))

df_gold.createOrReplaceTempView("v_gold_kpi")

print("✅ View 'v_gold_kpi' criada. Ranking de vendas pronto:")
display(spark.sql("SELECT * FROM v_gold_kpi"))
# Out:
# 🚀 [GOLD] Calculando KPIs de Vendas por Estado...
# ✅ View 'v_gold_kpi' criada. Ranking de vendas pronto:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>estado</th><th>total_vendas</th><th>qtd_transacoes</th></tr></thead><tbody><tr><td>GO</td><td>140020.68</td><td>59</td></tr><tr><td>SC</td><td>137817.61</td><td>52</td></tr><tr><td>RS</td><td>133707.29</td><td>50</td></tr><tr><td>BA</td><td>128113.43</td><td>51</td></tr><tr><td>MG</td><td>126498.22</td><td>50</td></tr><tr><td>AM</td><td>117723.33</td><td>53</td></tr><tr><td>SP</td><td>112558.73</td><td>44</td></tr><tr><td>PE</td><td>110712.25</td><td>53</td></tr><tr><td>DF</td><td>104137.17</td><td>45</td></tr><tr><td>RJ</td><td>96908.71</td><td>43</td></tr></tbody></table></div>

# %% [markdown]
# ###Data Observability

# %%
from pyspark.sql.functions import sum

print("🔍 Iniciando Auditoria de Integridade...")

try:
    qtd_bronze = spark.table("v_bronze_raw").count()
    qtd_silver = spark.table("v_silver_trusted").count()
    
    qtd_gold_recuperada = spark.table("v_gold_kpi").agg(sum("qtd_transacoes")).collect()[0][0]

    print(f"\n📊 RELATÓRIO DE VOLUMETRIA:")
    print(f"   🔹 Bronze (Raw):     {qtd_bronze} registros")
    print(f"   🔹 Silver (Trusted): {qtd_silver} registros")
    print(f"   🔹 Gold (Agg):       {qtd_gold_recuperada} registros (Soma das transações)")

    if qtd_bronze == qtd_silver == qtd_gold_recuperada:
        print("\n✅ SUCESSO TOTAL: O Pipeline processou 100% dos dados sem perdas!")
    else:
        print("\n❌ ALERTA CRÍTICO: Divergência de dados encontrada entre as camadas.")

except Exception as e:
    print(f"❌ Erro na auditoria: {e}. Verifique se todas as células anteriores rodaram.")
# Out:
# 🔍 Iniciando Auditoria de Integridade...
#
# 📊 RELATÓRIO DE VOLUMETRIA:
#    🔹 Bronze (Raw):     500 registros
#    🔹 Silver (Trusted): 500 registros
#    🔹 Gold (Agg):       500 registros (Soma das transações)
#
# ✅ SUCESSO TOTAL: O Pipeline processou 100% dos dados sem perdas!

# %% [markdown]
# ###Simulação de consulta do GOLD em estudo

# %%
# %sql
SELECT 
    estado,
    total_vendas,
    qtd_transacoes,
    concat('R$ ', format_number(total_vendas, 2)) as vendas_formatado
FROM v_gold_kpi
WHERE total_vendas > 5000
ORDER BY total_vendas DESC
LIMIT 27
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>estado</th><th>total_vendas</th><th>qtd_transacoes</th><th>vendas_formatado</th></tr></thead><tbody><tr><td>GO</td><td>140020.68</td><td>59</td><td>R$ 140,020.68</td></tr><tr><td>SC</td><td>137817.61</td><td>52</td><td>R$ 137,817.61</td></tr><tr><td>RS</td><td>133707.29</td><td>50</td><td>R$ 133,707.29</td></tr><tr><td>BA</td><td>128113.43</td><td>51</td><td>R$ 128,113.43</td></tr><tr><td>MG</td><td>126498.22</td><td>50</td><td>R$ 126,498.22</td></tr><tr><td>AM</td><td>117723.33</td><td>53</td><td>R$ 117,723.33</td></tr><tr><td>SP</td><td>112558.73</td><td>44</td><td>R$ 112,558.73</td></tr><tr><td>PE</td><td>110712.25</td><td>53</td><td>R$ 110,712.25</td></tr><tr><td>DF</td><td>104137.17</td><td>45</td><td>R$ 104,137.17</td></tr><tr><td>RJ</td><td>96908.71</td><td>43</td><td>R$ 96,908.71</td></tr></tbody></table></div>
